# %%
import hashlib
import datetime
import random

# %%
class Block:
    def __init__(self, previoushash, data, timestamp):
        self.previoushash = previoushash
        self.data = data
        self.timestamp = timestamp
        self.hash = self.get_hash()
    
    @staticmethod
    def create_genisis_block(data):
        return Block("0", data, datetime.datetime.now())
    def get_hash(self):
        header_bin = (str(self.previoushash)+
                     str(self.data)+
                     str(self.timestamp)).encode()
        
        inner_hash = hashlib.sha256(header_bin).hexdigest().encode()
        outer_hash = hashlib.sha256(inner_hash).hexdigest()
        return outer_hash

# %%
block_chain = [Block.create_genisis_block(2)]
print ("The Genesis block has been created ")
print ("Hash: "+str(block_chain[-1].hash))
print ("Hash data: "+str(block_chain[-1].data))
print ("Previous Hash: "+str(block_chain[-1].previoushash))
print ()
num_blocks_to_add = 10

for i in range(1,num_blocks_to_add+1):
    block_chain.append(Block(block_chain[-1].hash, random.randint(1,100)/40, datetime.datetime.now()))
    
    print ("BLock "+str(i)+" has been created.")
    print ("Block "+str(i)+" hash: "+str(block_chain[i].hash))
    print ("Block "+str(i)+" Previous hash: "+str(block_chain[i].previoushash))
    print ("Block "+str(i)+" Data: "+str(block_chain[i].data))
    print ("Block "+str(i)+" Timestamp: "+str(block_chain[i].timestamp))
    print()
# Out:
# The Genesis block has been created
# Hash: ca93dcbb7198e7e40bafb11890076df854694f1e801323ab3f9cfbe8a59ea843
# Hash data: 2
# Previous Hash: 0
#
# BLock 1 has been created.
# Block 1 hash: d7fd5b0fbc1d367502798bd79b930b29d3a6eb30adc238b58828edb3f52a7ad6
# Block 1 Previous hash: ca93dcbb7198e7e40bafb11890076df854694f1e801323ab3f9cfbe8a59ea843
# Block 1 Data: 1.125
# Block 1 Timestamp: 2018-04-06 23:40:04.586003
#
# BLock 2 has been created.
# Block 2 hash: 8fb3ac11fbff52a3a2aa7976ceb4c910536d8cb74d3fdbfef7195e19e6006c4d
# Block 2 Previous hash: d7fd5b0fbc1d367502798bd79b930b29d3a6eb30adc238b58828edb3f52a7ad6
# Block 2 Data: 2.325
# Block 2 Timestamp: 2018-04-06 23:40:04.587005
#
# BLock 3 has been created.
# Block 3 hash: 56996ec0ed910610290c73b2c324728da1fd2defdd8350c1d5ca2610d9178dfb
# Block 3 Previous hash: 8fb3ac11fbff52a3a2aa7976ceb4c910536d8cb74d3fdbfef7195e19e6006c4d
# Block 3 Data: 0.7
